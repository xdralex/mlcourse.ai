# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course
#
# Author: Mariya Mansurova, Analyst & developer in Yandex.Metrics team. Translated by Ivan Zakharov, ML enthusiast. <br>This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# # <center> Assignment #9 (demo)
# ## <center> Time series analysis
#
# **Same assignment as a [Kaggle Kernel](https://www.kaggle.com/kashnitsky/a9-demo-time-series-analysis) + [solution](https://www.kaggle.com/kashnitsky/a9-demo-time-series-analysis-solution).**
#
# **Fill cells marked with "Your code here" and submit your answers to the questions through the [web form](https://docs.google.com/forms/d/1UYQ_WYSpsV3VSlZAzhSN_YXmyjV7YlTP8EYMg8M8SoM/edit).**

# %%
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd

from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly import graph_objs as go
import requests

print(__version__) # need 1.9.0 or greater
init_notebook_mode(connected = True)


def plotly_df(df, title = ''):
    data = []
    
    for column in df.columns:
        trace = go.Scatter(
            x = df.index,
            y = df[column],
            mode = 'lines',
            name = column
        )
        data.append(trace)
    
    layout = dict(title = title)
    fig = dict(data = data, layout = layout)
    iplot(fig, show_link=False)
# Out:
# 3.6.0
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ## Data preparation

# %%
df = pd.read_csv('../../data/wiki_machine_learning.csv', sep = ' ')
df = df[df['count'] != 0]
df.head()
# Out:
#           date  count lang              page  rank   month             title
# 81  2015-01-01   1414   en  Machine_learning  8708  201501  Machine_learning
# 80  2015-01-02   1920   en  Machine_learning  8708  201501  Machine_learning
# 79  2015-01-03   1338   en  Machine_learning  8708  201501  Machine_learning
# 78  2015-01-04   1404   en  Machine_learning  8708  201501  Machine_learning
# 77  2015-01-05   2264   en  Machine_learning  8708  201501  Machine_learning

# %%
df.shape
# Out:
# (383, 7)

# %% [markdown]
# ## Predicting with FB Prophet
# We will train at first 5 months and predict the number of trips for June.

# %%
df.date = pd.to_datetime(df.date)

# %%
plotly_df(df.set_index('date')[['count']])
# Out:
# <div id="8177c117-97f4-4a50-aacb-99e2d9da1261" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8177c117-97f4-4a50-aacb-99e2d9da1261", [{"mode": "lines", "name": "count", "x": ["2015-01-01", "2015-01-02", "2015-01-03", "2015-01-04", "2015-01-05", "2015-01-06", "2015-01-07", "2015-01-08", "2015-01-09", "2015-01-10", "2015-01-11", "2015-01-12", "2015-01-13", "2015-01-14", "2015-01-15", "2015-01-16", "2015-01-17", "2015-01-18", "2015-01-19", "2015-01-20", "2015-01-21", "2015-01-22", "2015-01-23", "2015-01-24", "2015-01-25", "2015-01-26", "2015-01-27", "2015-01-28", "2015-01-29", "2015-01-30", "2015-01-31", "2015-02-01", "2015-02-02", "2015-02-03", "2015-02-04", "2015-02-06", "2015-02-07", "2015-02-08", "2015-02-09", "2015-02-10", "2015-02-11", "2015-02-12", "2015-02-13", "2015-02-14", "2015-02-15", "2015-02-16", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-21", "2015-02-22", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-02-28", "2015-03-01", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-07", "2015-03-08", "2015-03-09", "2015-03-10", "2015-03-11", "2015-03-12", "2015-03-13", "2015-03-14", "2015-03-15", "2015-03-16", "2015-03-17", "2015-03-18", "2015-03-19", "2015-03-20", "2015-03-21", "2015-03-22", "2015-03-23", "2015-03-24", "2015-03-25", "2015-03-26", "2015-03-27", "2015-03-28", "2015-03-29", "2015-03-30", "2015-03-31", "2015-04-01", "2015-04-02", "2015-04-03", "2015-04-04", "2015-04-05", "2015-04-06", "2015-04-07", "2015-04-08", "2015-04-09", "2015-04-10", "2015-04-11", "2015-04-12", "2015-04-13", "2015-04-14", "2015-04-15", "2015-04-16", "2015-04-17", "2015-04-18", "2015-04-19", "2015-04-20", "2015-04-21", "2015-04-22", "2015-04-23", "2015-04-24", "2015-04-25", "2015-04-26", "2015-04-27", "2015-04-28", "2015-04-29", "2015-04-30", "2015-05-01", "2015-05-02", "2015-05-03", "2015-05-04", "2015-05-05", "2015-05-06", "2015-05-07", "2015-05-08", "2015-05-09", "2015-05-10", "2015-05-11", "2015-05-12", "2015-05-13", "2015-05-14", "2015-05-15", "2015-05-16", "2015-05-17", "2015-05-18", "2015-05-19", "2015-05-20", "2015-05-21", "2015-05-22", "2015-05-23", "2015-05-24", "2015-05-25", "2015-05-26", "2015-05-27", "2015-05-28", "2015-05-29", "2015-05-30", "2015-05-31", "2015-06-01", "2015-06-02", "2015-06-03", "2015-06-04", "2015-06-05", "2015-06-06", "2015-06-07", "2015-06-08", "2015-06-09", "2015-06-10", "2015-06-11", "2015-06-12", "2015-06-13", "2015-06-14", "2015-06-15", "2015-06-16", "2015-06-17", "2015-06-18", "2015-06-19", "2015-06-20", "2015-06-21", "2015-06-22", "2015-06-23", "2015-06-24", "2015-06-25", "2015-06-26", "2015-06-27", "2015-06-28", "2015-06-29", "2015-06-30", "2015-07-01", "2015-07-02", "2015-07-03", "2015-07-04", "2015-07-05", "2015-07-06", "2015-07-07", "2015-07-08", "2015-07-09", "2015-07-10", "2015-07-11", "2015-07-12", "2015-07-13", "2015-07-14", "2015-07-15", "2015-07-16", "2015-07-17", "2015-07-18", "2015-07-19", "2015-07-20", "2015-07-21", "2015-07-22", "2015-07-23", "2015-07-24", "2015-07-25", "2015-07-26", "2015-07-27", "2015-07-28", "2015-07-29", "2015-07-30", "2015-07-31", "2015-08-01", "2015-08-02", "2015-08-03", "2015-08-04", "2015-08-05", "2015-08-06", "2015-08-07", "2015-08-08", "2015-08-09", "2015-08-10", "2015-08-11", "2015-08-12", "2015-08-13", "2015-08-14", "2015-08-15", "2015-08-16", "2015-08-17", "2015-08-18", "2015-08-19", "2015-08-20", "2015-08-21", "2015-08-22", "2015-08-23", "2015-08-24", "2015-08-25", "2015-08-26", "2015-08-27", "2015-08-28", "2015-08-29", "2015-08-30", "2015-08-31", "2015-09-01", "2015-09-02", "2015-09-03", "2015-09-04", "2015-09-05", "2015-09-06", "2015-09-07", "2015-09-08", "2015-09-09", "2015-09-10", "2015-09-11", "2015-09-12", "2015-09-13", "2015-09-14", "2015-09-15", "2015-09-16", "2015-09-17", "2015-09- ...

# %%
from fbprophet import Prophet

# %%
predictions = 30

df = df[['date', 'count']]
df.columns = ['ds', 'y']
df.tail()
# Out:
#             ds     y
# 382 2016-01-16  1644
# 381 2016-01-17  1836
# 376 2016-01-18  2983
# 375 2016-01-19  3389
# 372 2016-01-20  3559

# %% [markdown]
# **<font color='red'>Question 1:</font>** What is the prediction of the number of views of the wiki page on January 20? Round to the nearest integer.
#
# - 4947
# - 3426
# - 5229
# - 2744

# %%
train_df = df[:-predictions]

m = Prophet()
m.fit(train_df)

future = m.make_future_dataframe(periods=predictions)

forecast = m.predict(future)
forecast.tail(n=3)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 380 2016-01-18  2990.135281  2859.961496  3664.931045  2969.873257
# 381 2016-01-19  2995.542971  3107.812131  3949.016934  2973.975971
# 382 2016-01-20  3000.950660  3008.117690  3841.280387  2978.410791
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 380  3012.582807      281.357669            281.357669            281.357669
# 381  3018.918149      541.423837            541.423837            541.423837
# 382  3025.232632      425.547911            425.547911            425.547911
#
#          weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 380  281.357669    281.357669    281.357669                   0.0
# 381  541.423837    541.423837    541.423837                   0.0
# 382  425.547911    425.547911    425.547911                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 380                         0.0                         0.0  3271.492950
# 381                         0.0                         0.0  3536.966808
# 382                         0.0                         0.0  3426.498570

# %%
train_df.tail()
# Out:
#             ds     y
# 358 2015-12-17  2870
# 363 2015-12-18  2475
# 364 2015-12-19  1659
# 344 2015-12-20  1534
# 343 2015-12-21  2425

# %%
forecast.tail()
# Out:
#             ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 378 2016-01-16  2979.319903  1739.133528  2541.440641  2961.456169
# 379 2016-01-17  2984.727592  1864.988503  2666.308200  2965.612995
# 380 2016-01-18  2990.135281  2859.961496  3664.931045  2969.873257
# 381 2016-01-19  2995.542971  3107.812131  3949.016934  2973.975971
# 382 2016-01-20  3000.950660  3008.117690  3841.280387  2978.410791
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 378  3000.071234     -861.693311           -861.693311           -861.693311
# 379  3006.396961     -720.705354           -720.705354           -720.705354
# 380  3012.582807      281.357669            281.357669            281.357669
# 381  3018.918149      541.423837            541.423837            541.423837
# 382  3025.232632      425.547911            425.547911            425.547911
#
#          weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 378 -861.693311   -861.693311   -861.693311                   0.0
# 379 -720.705354   -720.705354   -720.705354                   0.0
# 380  281.357669    281.357669    281.357669                   0.0
# 381  541.423837    541.423837    541.423837                   0.0
# 382  425.547911    425.547911    425.547911                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 378                         0.0                         0.0  2117.626592
# 379                         0.0                         0.0  2264.022238
# 380                         0.0                         0.0  3271.492950
# 381                         0.0                         0.0  3536.966808
# 382                         0.0                         0.0  3426.498570

# %% [markdown]
# Estimate the quality of the prediction with the last 30 points.

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
def errors(cmp):
    e = cmp['y'] - cmp['yhat']
    print('MAE = %.4f' % np.mean(np.abs(e)))
    print('MAPE = %.4f' % (100 * np.mean(np.abs(e / cmp['y']))))
    

cmp = pd.merge(forecast, df, how='inner', on='ds')
cmp = cmp[-predictions:]
    
errors(cmp)
# Out:
# MAE = 599.8383
# MAPE = 34.5029

# %% [markdown]
# **<font color='red'>Question 2:</font> What is MAPE equal to?**
#
# - 34.5
# - 42.42
# - 5.39
# - 65.91
#
# **<font color='red'>Question 3:</font> What is MAE equal to?**
#
# - 355
# - 4007
# - 600
# - 903

# %% [markdown]
# ## Predicting with ARIMA

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

plt.rcParams['figure.figsize'] = (15, 10)

# %% [markdown]
# **<font color='red'>Question 4:</font> Let's verify the stationarity of the series using the Dickey-Fuller test. Is the series stationary? What is the p-value?**
#
# - Series is stationary, p_value = 0.107
# - Series is not stationary, p_value = 0.107
# - Series is stationary, p_value = 0.001
# - Series is not stationary, p_value = 0.001

# %%
sm.tsa.stattools.adfuller(train_df['y'])
# Out:
# (-2.534117843418302,
#  0.1073921962761209,
#  15,
#  337,
#  {'1%': -3.4499043309021955,
#   '5%': -2.870154885338925,
#   '10%': -2.5713597190254385},
#  4878.896813791136)

# %%
sm.tsa.seasonal_decompose(train_df['y'].values, freq=7).plot();

# %% [markdown]
# **Next, we turn to the construction of the SARIMAX model (`sm.tsa.statespace.SARIMAX`).<br> <font color='red'>Question 5:</font> What parameters are the best for the model according to the `AIC` criterion?**
#
# - D = 1, d = 0, Q = 0, q = 2, P = 3, p = 1
# - D = 2, d = 1, Q = 1, q = 2, P = 3, p = 1
# - D = 1, d = 1, Q = 1, q = 2, P = 3, p = 1
# - D = 0, d = 0, Q = 0, q = 2, P = 3, p = 1

# %%
# You code here
